# %%
# !pip install arch yfinance > log.txt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from arch import arch_model
import yfinance as yf
from datetime import timedelta
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

import warnings
warnings.filterwarnings("ignore")

# %%
def get_hourly_data(name='BTC', start='2024-01-01', end='2024-10-01'):
    data = yf.download(f'{name}-USD', start=start, end=end, interval='1h')
    data['Returns'] = 100 * data['Adj Close'].pct_change().dropna()
    return data

def get_daily_data(name='BTC', start='2024-01-01', end='2024-10-01'):
    data = yf.download(f'{name}-USD', start=start, end=end)
    data['Returns'] = 100 * data['Adj Close'].pct_change().dropna()
    return data

daily_data = get_daily_data('ETH', start='2024-01-01', end='2024-10-01')
hourly_data = get_hourly_data('ETH', start='2024-01-01', end='2024-10-01')

daily_returns = daily_data['Returns'].dropna()
hourly_returns = hourly_data['Returns'].dropna()

# %%
def calculate_daily_realized_volatility(hourly_returns):
    daily_volatility = hourly_returns.resample('D').std()  # Daily std from hourly returns
    return daily_volatility * np.sqrt(24)

daily_realized_volatility = calculate_daily_realized_volatility(hourly_returns)

# %%
def get_rolling_garch_predictions(returns, model_params, window_size=100):
    vol_forecast = []
    for i in range(window_size, len(returns)):
        window_data = returns[:i]
        model = arch_model(window_data, **model_params)
        garch_fit = model.fit(disp="off", options={'maxiter': 350})
        # Forecast one-step ahead volatility
        vol_forecast.append(garch_fit.forecast(horizon=1).variance.values[-1, :][0])
    
    # Align the forecast with the returns data
    vol_forecast = pd.Series(vol_forecast, index=returns.index[window_size:])
    return np.sqrt(vol_forecast)

def get_naive_predictions(daily_realized_volatility):
    return daily_realized_volatility.shift(1)

# %%
def plot_predictions(realized_volatility, predictions):
    plt.figure(figsize=(12, 6))
    realized_volatility_trimmed = (realized_volatility - predictions).dropna() + predictions
    plt.plot(realized_volatility_trimmed.index, realized_volatility_trimmed, label='Realized Volatility', color='blue')
    plt.plot(predictions.index, predictions, label='Predicted Volatility', color='red')
    plt.title('Predicted vs. Realized Volatility')
    plt.xlabel('Date')
    plt.ylabel('Volatility (%)')
    plt.legend()
    plt.grid()
    plt.show()
    
def plot_conic(returns, volatility):
    plt.scatter(returns, volatility)
    

def calculate_metrics(realized_volatility, predictions):
    return {
        'MSE': ((realized_volatility - predictions).dropna()**2).mean(),
        'MAE': np.abs(realized_volatility - predictions).dropna().mean()
    }

# %%
model_params = {'vol': 'garch', 'q': 1, 'p': 1}
garch_predictions = get_rolling_garch_predictions(daily_returns, model_params)

naive_predictions = get_naive_predictions(daily_realized_volatility)

# %%
plot_predictions(daily_realized_volatility, garch_predictions)

# %%
plot_predictions(daily_realized_volatility, naive_predictions)

# %%
calculate_metrics(daily_realized_volatility, garch_predictions)

# %%
calculate_metrics(daily_realized_volatility, naive_predictions)

# %%
def plot_table(data):
    table = pd.DataFrame(data, columns=["Model", "MSE", "MAE", 'MSSE', 'MASE'])
    plt.figure(figsize=(8, 4))
    sns.set(style="whitegrid")
    styled_table = table.style.background_gradient(cmap="Oranges", subset=['MSSE', 'MASE'])
    styled_table = styled_table.set_properties(**{'text-align': 'center'})
    display(styled_table)

def grid_fit_model(daily_realized_volatility, daily_returns, model_name='GARCH', dist='Normal', mse_naive=1, mae_naive=1, p_start=1, p_end=1, q_start=1, q_end=1, o_start=0, o_end=0):
    table = []
    table.append(['naive', round(mse_naive, 3), round(mae_naive, 3), 1, 1])

    for p in range(p_start, p_end+1):
        for q in range(q_start, q_end+1):
            for o in range(o_start, o_end+1):
                if model_name == 'GJR-GARCH':
                    model_params = {'vol': 'GARCH', 'q': q, 'p': p, 'o': 1, 'dist': dist}
                else:
                    model_params = {'vol': model_name, 'q': q, 'p': p, 'o': o, 'dist': dist}
                garch_predictions = get_rolling_garch_predictions(daily_returns, model_params)

                metrics = calculate_metrics(daily_realized_volatility, garch_predictions)

                mse = metrics['MSE']
                mae = metrics['MAE']
                msse = mse_naive / metrics['MSE']
                mase = mae_naive / metrics['MAE']

                table.append([f'{model_name}(p={str(p)}, q={str(q)}, o={str(o)})', mse, mae, msse, mase])

    return table

# %%
naive_model_metrics = calculate_metrics(daily_realized_volatility, naive_predictions)
naive_mse = naive_model_metrics['MSE']
naive_mae = naive_model_metrics['MAE']

# %%
garch_table = grid_fit_model(daily_realized_volatility=daily_realized_volatility,
                             daily_returns = daily_returns,
                             model_name='ARCH',
                             mse_naive=naive_mse,
                             mae_naive=naive_mae,
                             p_start=1, p_end=2, q_start=1, q_end=2)
plot_table(garch_table)
# Out:
# <style type="text/css">
# #T_64b9a_row0_col0, #T_64b9a_row0_col1, #T_64b9a_row0_col2, #T_64b9a_row1_col0, #T_64b9a_row1_col1, #T_64b9a_row1_col2, #T_64b9a_row2_col0, #T_64b9a_row2_col1, #T_64b9a_row2_col2, #T_64b9a_row3_col0, #T_64b9a_row3_col1, #T_64b9a_row3_col2, #T_64b9a_row4_col0, #T_64b9a_row4_col1, #T_64b9a_row4_col2, #T_64b9a_row5_col0, #T_64b9a_row5_col1, #T_64b9a_row5_col2, #T_64b9a_row6_col0, #T_64b9a_row6_col1, #T_64b9a_row6_col2, #T_64b9a_row7_col0, #T_64b9a_row7_col1, #T_64b9a_row7_col2, #T_64b9a_row8_col0, #T_64b9a_row8_col1, #T_64b9a_row8_col2, #T_64b9a_row9_col0, #T_64b9a_row9_col1, #T_64b9a_row9_col2 {
#   text-align: center;
# }
# #T_64b9a_row0_col3, #T_64b9a_row0_col4 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
# }
# #T_64b9a_row1_col3, #T_64b9a_row2_col3, #T_64b9a_row3_col3, #T_64b9a_row7_col4, #T_64b9a_row8_col4, #T_64b9a_row9_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_64b9a_row1_col4, #T_64b9a_row2_col4, #T_64b9a_row3_col4 {
#   background-color: #fdd9b4;
#   color: #000000;
#   text-align: center;
# }
# #T_64b9a_row4_col3, #T_64b9a_row5_col3, #T_64b9a_row6_col3 {
#   background-color: #a03403;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_64b9a_row4_col4, #T_64b9a_row5_col4, #T_64b9a_row6_col4 {
#   background-color: #fedfc0;
#   color: #000000;
#   text-align: center;
# }
# #T_64b9a_row7_col3, #T_64b9a_row8_col3, #T_64b9a_row9_col3 {
#   background-color: #a53603;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_64b9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64b9a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_64b9a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_64b9a_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_64b9a_level0_col3" class="col_heading level0 col3" >MSSE</th>
#       <th id="T_64b9a_level0_col4" class="col_heading level0 col4" >MASE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64b9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64b9a_row0_col0" class="data row0 col0" >naive</td>
#       <td id="T_64b9a_row0_col1" class="data row0 col1" >3.070000</td>
#       <td id="T_64b9a_row0_col2" class="data row0 col2" >1.219000</td>
#       <td id="T_64b9a_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_64b9a_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64b9a_row1_col0" class="data row1 col0" >ARCH(p=1, q=1, o=0)</td>
#       <td id="T_64b9a_row1_col1" class="data row1 col1" >2.808439</td>
#       <td id="T_64b9a_row1_col2" class="data row1 col2" >1.208198</td>
#       <td id="T_64b9a_row1_col3" class="data row1 col3" >1.093103</td>
#       <td id="T_64b9a_row1_col4" class="data row1 col4" >1.008533</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64b9a_row2_col0" class="data row2 col0" >ARCH(p=1, q=2, o=0)</td>
#       <td id="T_64b9a_row2_col1" class="data row2 col1" >2.808439</td>
#       <td id="T_64b9a_row2_col2" class="data row2 col2" >1.208198</td>
#       <td id="T_64b9a_row2_col3" class="data row2 col3" >1.093103</td>
#       <td id="T_64b9a_row2_col4" class="data row2 col4" >1.008533</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64b9a_row3_col0" class="data row3 col0" >ARCH(p=1, q=3, o=0)</td>
#       <td id="T_64b9a_row3_col1" class="data row3 col1" >2.808439</td>
#       <td id="T_64b9a_row3_col2" class="data row3 col2" >1.208198</td>
#       <td id="T_64b9a_row3_col3" class="data row3 col3" >1.093103</td>
#       <td id="T_64b9a_row3_col4" class="data row3 col4" >1.008533</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64b9a_row4_col0" class="data row4 col0" >ARCH(p=2, q=1, o=0)</td>
#       <td id="T_64b9a_row4_col1" class="data row4 col1" >2.834660</td>
#       <td id="T_64b9a_row4_col2" class="data row4 col2" >1.210107</td>
#       <td id="T_64b9a_row4_col3" class="data row4 col3" >1.082992</td>
#       <td id="T_64b9a_row4_col4" class="data row4 col4" >1.006943</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64b9a_row5_col0" class="data row5 col0" >ARCH(p=2, q=2, o=0)</td>
#       <td id="T_64b9a_row5_col1" class="data row5 col1" >2.834660</td>
#       <td id="T_64b9a_row5_col2" class="data row5 col2" >1.210107</td>
#       <td id="T_64b9a_row5_col3" class="data row5 col3" >1.082992</td>
#       <td id="T_64b9a_row5_col4" class="data row5 col4" >1.006943</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64b9a_row6_col0" class="data row6 col0" >ARCH(p=2, q=3, o=0)</td>
#       <td id="T_64b9a_row6_col1" class="data row6 col1" >2.834660</td>
#       <td id="T_64b9a_row6_col2" class="data row6 col2" >1.210107</td>
#       <td id="T_64b9a_row6_col3" class="data row6 col3" >1.082992</td>
#       <td id="T_64b9a_row6_col4" class="data row6 col4" >1.006943</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64b9a_row7_col0" class="data row7 col0" >ARCH(p=3, q=1, o=0)</td>
#       <td id="T_64b9a_row7_col1" class="data row7 col1" >2.838489</td>
#       <td id="T_64b9a_row7_col2" class="data row7 col2" >1.169110</td>
#       <td id="T_64b9a_row7_col3" class="data row7 col3" >1.081531</td>
#       <td id="T_64b9a_row7_col4" class="data row7 col4" >1.042253</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64b9a_row8_col0" class="data row8 col0" >ARCH(p=3, q=2, o=0)</td>
#       <td id="T_64b9a_row8_col1" class="data row8 col1" >2.838489</td>
#       <td id="T_64b9a_row8_col2" class="data row8 col2" >1.169110</td>
#       <td id="T_64b9a_row8_col3" class="data row8 col3" >1.081531</td>
#       <td id="T_64b9a_row8_col4" class="data row8 col4" >1.042253</td>
#     </tr>
#     <tr>
#       <th id="T_64b9a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64b9a_row9_col0" class="data row9 col0" >ARCH(p=3, q=3, o=0)</td>
#       <td id="T_64b9a_row9_col1" class="data row9 col1" >2.838489</td>
#       <td id="T_64b9a_row9_col2" class="data row9 col2" >1.169110</td>
#       <td id="T_64b9a_row9_col3" class="data row9 col3" >1.081531</td>
#       <td id="T_64b9a_row9_col4" class="data row9 col4" >1.042253</td>
#     </tr>
#   </tbody>
# </table>

# %%
garch_table = grid_fit_model(daily_realized_volatility=daily_realized_volatility,
                             daily_returns = daily_returns,
                             model_name='GARCH',
                             mse_naive=naive_mse,
                             mae_naive=naive_mae,
                             p_start=1, p_end=2, q_start=1, q_end=2)
plot_table(garch_table)
# Out:
# <style type="text/css">
# #T_1b22b_row0_col0, #T_1b22b_row0_col1, #T_1b22b_row0_col2, #T_1b22b_row1_col0, #T_1b22b_row1_col1, #T_1b22b_row1_col2, #T_1b22b_row2_col0, #T_1b22b_row2_col1, #T_1b22b_row2_col2, #T_1b22b_row3_col0, #T_1b22b_row3_col1, #T_1b22b_row3_col2, #T_1b22b_row4_col0, #T_1b22b_row4_col1, #T_1b22b_row4_col2 {
#   text-align: center;
# }
# #T_1b22b_row0_col3, #T_1b22b_row0_col4 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
# }
# #T_1b22b_row1_col3 {
#   background-color: #c03f02;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1b22b_row1_col4 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1b22b_row2_col3, #T_1b22b_row2_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1b22b_row3_col3 {
#   background-color: #e25508;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1b22b_row3_col4 {
#   background-color: #fdab66;
#   color: #000000;
#   text-align: center;
# }
# #T_1b22b_row4_col3 {
#   background-color: #8c2c04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1b22b_row4_col4 {
#   background-color: #9b3203;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_1b22b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b22b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1b22b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1b22b_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_1b22b_level0_col3" class="col_heading level0 col3" >MSSE</th>
#       <th id="T_1b22b_level0_col4" class="col_heading level0 col4" >MASE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b22b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b22b_row0_col0" class="data row0 col0" >naive</td>
#       <td id="T_1b22b_row0_col1" class="data row0 col1" >3.070000</td>
#       <td id="T_1b22b_row0_col2" class="data row0 col2" >1.219000</td>
#       <td id="T_1b22b_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_1b22b_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1b22b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b22b_row1_col0" class="data row1 col0" >GARCH(p=1, q=1, o=0)</td>
#       <td id="T_1b22b_row1_col1" class="data row1 col1" >2.771688</td>
#       <td id="T_1b22b_row1_col2" class="data row1 col2" >1.181610</td>
#       <td id="T_1b22b_row1_col3" class="data row1 col3" >1.107597</td>
#       <td id="T_1b22b_row1_col4" class="data row1 col4" >1.031228</td>
#     </tr>
#     <tr>
#       <th id="T_1b22b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b22b_row2_col0" class="data row2 col0" >GARCH(p=1, q=2, o=0)</td>
#       <td id="T_1b22b_row2_col1" class="data row2 col1" >2.710519</td>
#       <td id="T_1b22b_row2_col2" class="data row2 col2" >1.147842</td>
#       <td id="T_1b22b_row2_col3" class="data row2 col3" >1.132593</td>
#       <td id="T_1b22b_row2_col4" class="data row2 col4" >1.061564</td>
#     </tr>
#     <tr>
#       <th id="T_1b22b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b22b_row3_col0" class="data row3 col0" >GARCH(p=2, q=1, o=0)</td>
#       <td id="T_1b22b_row3_col1" class="data row3 col1" >2.808930</td>
#       <td id="T_1b22b_row3_col2" class="data row3 col2" >1.189920</td>
#       <td id="T_1b22b_row3_col3" class="data row3 col3" >1.092912</td>
#       <td id="T_1b22b_row3_col4" class="data row3 col4" >1.024026</td>
#     </tr>
#     <tr>
#       <th id="T_1b22b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b22b_row4_col0" class="data row4 col0" >GARCH(p=2, q=2, o=0)</td>
#       <td id="T_1b22b_row4_col1" class="data row4 col1" >2.725083</td>
#       <td id="T_1b22b_row4_col2" class="data row4 col2" >1.153926</td>
#       <td id="T_1b22b_row4_col3" class="data row4 col3" >1.126540</td>
#       <td id="T_1b22b_row4_col4" class="data row4 col4" >1.055967</td>
#     </tr>
#   </tbody>
# </table>

# %%
garch_table = grid_fit_model(daily_realized_volatility=daily_realized_volatility,
                             daily_returns = daily_returns,
                             model_name='EGARCH',
                             mse_naive=naive_mse,
                             mae_naive=naive_mae,
                             p_start=1, p_end=2, q_start=1, q_end=2, o_start=0, o_end=1)
plot_table(garch_table)
# Out:
# <style type="text/css">
# #T_3e702_row0_col0, #T_3e702_row0_col1, #T_3e702_row0_col2, #T_3e702_row1_col0, #T_3e702_row1_col1, #T_3e702_row1_col2, #T_3e702_row2_col0, #T_3e702_row2_col1, #T_3e702_row2_col2, #T_3e702_row3_col0, #T_3e702_row3_col1, #T_3e702_row3_col2, #T_3e702_row4_col0, #T_3e702_row4_col1, #T_3e702_row4_col2, #T_3e702_row5_col0, #T_3e702_row5_col1, #T_3e702_row5_col2, #T_3e702_row6_col0, #T_3e702_row6_col1, #T_3e702_row6_col2, #T_3e702_row7_col0, #T_3e702_row7_col1, #T_3e702_row7_col2, #T_3e702_row8_col0, #T_3e702_row8_col1, #T_3e702_row8_col2 {
#   text-align: center;
# }
# #T_3e702_row0_col3, #T_3e702_row0_col4 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
# }
# #T_3e702_row1_col3 {
#   background-color: #fa8532;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row1_col4 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row2_col3, #T_3e702_row2_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row3_col3 {
#   background-color: #f26d17;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row3_col4 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row4_col3 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row4_col4 {
#   background-color: #be3f02;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row5_col3 {
#   background-color: #fdd9b5;
#   color: #000000;
#   text-align: center;
# }
# #T_3e702_row5_col4 {
#   background-color: #feecd9;
#   color: #000000;
#   text-align: center;
# }
# #T_3e702_row6_col3 {
#   background-color: #8e2d04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row6_col4 {
#   background-color: #a43503;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row7_col3 {
#   background-color: #f9812e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row7_col4 {
#   background-color: #f36e19;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row8_col3 {
#   background-color: #c34002;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3e702_row8_col4 {
#   background-color: #d34601;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_3e702">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e702_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3e702_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3e702_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_3e702_level0_col3" class="col_heading level0 col3" >MSSE</th>
#       <th id="T_3e702_level0_col4" class="col_heading level0 col4" >MASE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e702_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e702_row0_col0" class="data row0 col0" >naive</td>
#       <td id="T_3e702_row0_col1" class="data row0 col1" >3.070000</td>
#       <td id="T_3e702_row0_col2" class="data row0 col2" >1.219000</td>
#       <td id="T_3e702_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_3e702_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e702_row1_col0" class="data row1 col0" >EGARCH(p=1, q=1, o=0)</td>
#       <td id="T_3e702_row1_col1" class="data row1 col1" >2.558947</td>
#       <td id="T_3e702_row1_col2" class="data row1 col2" >1.143397</td>
#       <td id="T_3e702_row1_col3" class="data row1 col3" >1.199679</td>
#       <td id="T_3e702_row1_col4" class="data row1 col4" >1.065691</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e702_row2_col0" class="data row2 col0" >EGARCH(p=1, q=1, o=1)</td>
#       <td id="T_3e702_row2_col1" class="data row2 col1" >2.228538</td>
#       <td id="T_3e702_row2_col2" class="data row2 col2" >1.077032</td>
#       <td id="T_3e702_row2_col3" class="data row2 col3" >1.377546</td>
#       <td id="T_3e702_row2_col4" class="data row2 col4" >1.131358</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e702_row3_col0" class="data row3 col0" >EGARCH(p=1, q=2, o=0)</td>
#       <td id="T_3e702_row3_col1" class="data row3 col1" >2.494752</td>
#       <td id="T_3e702_row3_col2" class="data row3 col2" >1.119388</td>
#       <td id="T_3e702_row3_col3" class="data row3 col3" >1.230549</td>
#       <td id="T_3e702_row3_col4" class="data row3 col4" >1.088549</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e702_row4_col0" class="data row4 col0" >EGARCH(p=1, q=2, o=1)</td>
#       <td id="T_3e702_row4_col1" class="data row4 col1" >2.344059</td>
#       <td id="T_3e702_row4_col2" class="data row4 col2" >1.100893</td>
#       <td id="T_3e702_row4_col3" class="data row4 col3" >1.309657</td>
#       <td id="T_3e702_row4_col4" class="data row4 col4" >1.106836</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3e702_row5_col0" class="data row5 col0" >EGARCH(p=2, q=1, o=0)</td>
#       <td id="T_3e702_row5_col1" class="data row5 col1" >2.858235</td>
#       <td id="T_3e702_row5_col2" class="data row5 col2" >1.205602</td>
#       <td id="T_3e702_row5_col3" class="data row5 col3" >1.074060</td>
#       <td id="T_3e702_row5_col4" class="data row5 col4" >1.010705</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3e702_row6_col0" class="data row6 col0" >EGARCH(p=2, q=1, o=1)</td>
#       <td id="T_3e702_row6_col1" class="data row6 col1" >2.259454</td>
#       <td id="T_3e702_row6_col2" class="data row6 col2" >1.092327</td>
#       <td id="T_3e702_row6_col3" class="data row6 col3" >1.358697</td>
#       <td id="T_3e702_row6_col4" class="data row6 col4" >1.115516</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3e702_row7_col0" class="data row7 col0" >EGARCH(p=2, q=2, o=0)</td>
#       <td id="T_3e702_row7_col1" class="data row7 col1" >2.548274</td>
#       <td id="T_3e702_row7_col2" class="data row7 col2" >1.128376</td>
#       <td id="T_3e702_row7_col3" class="data row7 col3" >1.204703</td>
#       <td id="T_3e702_row7_col4" class="data row7 col4" >1.079878</td>
#     </tr>
#     <tr>
#       <th id="T_3e702_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3e702_row8_col0" class="data row8 col0" >EGARCH(p=2, q=2, o=1)</td>
#       <td id="T_3e702_row8_col1" class="data row8 col1" >2.355662</td>
#       <td id="T_3e702_row8_col2" class="data row8 col2" >1.107610</td>
#       <td id="T_3e702_row8_col3" class="data row8 col3" >1.303206</td>
#       <td id="T_3e702_row8_col4" class="data row8 col4" >1.100124</td>
#     </tr>
#   </tbody>
# </table>

# %%
garch_table = grid_fit_model(daily_realized_volatility=daily_realized_volatility,
                             daily_returns = daily_returns,
                             model_name='GJR-GARCH',
                             mse_naive=naive_mse,
                             mae_naive=naive_mae,
                             p_start=1, p_end=3, q_start=1, q_end=3)
plot_table(garch_table)
# Out:
# <style type="text/css">
# #T_bd7d6_row0_col0, #T_bd7d6_row0_col1, #T_bd7d6_row0_col2, #T_bd7d6_row1_col0, #T_bd7d6_row1_col1, #T_bd7d6_row1_col2, #T_bd7d6_row2_col0, #T_bd7d6_row2_col1, #T_bd7d6_row2_col2, #T_bd7d6_row3_col0, #T_bd7d6_row3_col1, #T_bd7d6_row3_col2, #T_bd7d6_row4_col0, #T_bd7d6_row4_col1, #T_bd7d6_row4_col2, #T_bd7d6_row5_col0, #T_bd7d6_row5_col1, #T_bd7d6_row5_col2, #T_bd7d6_row6_col0, #T_bd7d6_row6_col1, #T_bd7d6_row6_col2, #T_bd7d6_row7_col0, #T_bd7d6_row7_col1, #T_bd7d6_row7_col2, #T_bd7d6_row8_col0, #T_bd7d6_row8_col1, #T_bd7d6_row8_col2, #T_bd7d6_row9_col0, #T_bd7d6_row9_col1, #T_bd7d6_row9_col2 {
#   text-align: center;
# }
# #T_bd7d6_row0_col3, #T_bd7d6_row0_col4 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
# }
# #T_bd7d6_row1_col3 {
#   background-color: #c34002;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row1_col4 {
#   background-color: #e35608;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row2_col3, #T_bd7d6_row7_col3 {
#   background-color: #832804;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row2_col4 {
#   background-color: #b53b02;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row3_col3 {
#   background-color: #882a04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row3_col4 {
#   background-color: #b13a03;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row4_col3 {
#   background-color: #d54601;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row4_col4 {
#   background-color: #ed6310;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row5_col3 {
#   background-color: #842904;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row5_col4 {
#   background-color: #b63c02;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row6_col3 {
#   background-color: #9a3103;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row6_col4 {
#   background-color: #d04501;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row7_col4, #T_bd7d6_row9_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row8_col3 {
#   background-color: #c94202;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row8_col4 {
#   background-color: #d14501;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd7d6_row9_col4 {
#   background-color: #a63603;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_bd7d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd7d6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bd7d6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bd7d6_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_bd7d6_level0_col3" class="col_heading level0 col3" >MSSE</th>
#       <th id="T_bd7d6_level0_col4" class="col_heading level0 col4" >MASE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd7d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd7d6_row0_col0" class="data row0 col0" >naive</td>
#       <td id="T_bd7d6_row0_col1" class="data row0 col1" >3.070000</td>
#       <td id="T_bd7d6_row0_col2" class="data row0 col2" >1.219000</td>
#       <td id="T_bd7d6_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_bd7d6_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd7d6_row1_col0" class="data row1 col0" >GJR-GARCH(p=1, q=1)</td>
#       <td id="T_bd7d6_row1_col1" class="data row1 col1" >2.396740</td>
#       <td id="T_bd7d6_row1_col2" class="data row1 col2" >1.103675</td>
#       <td id="T_bd7d6_row1_col3" class="data row1 col3" >1.280871</td>
#       <td id="T_bd7d6_row1_col4" class="data row1 col4" >1.104046</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bd7d6_row2_col0" class="data row2 col0" >GJR-GARCH(p=1, q=2)</td>
#       <td id="T_bd7d6_row2_col1" class="data row2 col1" >2.282263</td>
#       <td id="T_bd7d6_row2_col2" class="data row2 col2" >1.083521</td>
#       <td id="T_bd7d6_row2_col3" class="data row2 col3" >1.345119</td>
#       <td id="T_bd7d6_row2_col4" class="data row2 col4" >1.124582</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bd7d6_row3_col0" class="data row3 col0" >GJR-GARCH(p=1, q=3)</td>
#       <td id="T_bd7d6_row3_col1" class="data row3 col1" >2.289879</td>
#       <td id="T_bd7d6_row3_col2" class="data row3 col2" >1.082453</td>
#       <td id="T_bd7d6_row3_col3" class="data row3 col3" >1.340645</td>
#       <td id="T_bd7d6_row3_col4" class="data row3 col4" >1.125692</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bd7d6_row4_col0" class="data row4 col0" >GJR-GARCH(p=2, q=1)</td>
#       <td id="T_bd7d6_row4_col1" class="data row4 col1" >2.424591</td>
#       <td id="T_bd7d6_row4_col2" class="data row4 col2" >1.111675</td>
#       <td id="T_bd7d6_row4_col3" class="data row4 col3" >1.266158</td>
#       <td id="T_bd7d6_row4_col4" class="data row4 col4" >1.096101</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bd7d6_row5_col0" class="data row5 col0" >GJR-GARCH(p=2, q=2)</td>
#       <td id="T_bd7d6_row5_col1" class="data row5 col1" >2.282828</td>
#       <td id="T_bd7d6_row5_col2" class="data row5 col2" >1.083812</td>
#       <td id="T_bd7d6_row5_col3" class="data row5 col3" >1.344786</td>
#       <td id="T_bd7d6_row5_col4" class="data row5 col4" >1.124280</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bd7d6_row6_col0" class="data row6 col0" >GJR-GARCH(p=2, q=3)</td>
#       <td id="T_bd7d6_row6_col1" class="data row6 col1" >2.327293</td>
#       <td id="T_bd7d6_row6_col2" class="data row6 col2" >1.092752</td>
#       <td id="T_bd7d6_row6_col3" class="data row6 col3" >1.319093</td>
#       <td id="T_bd7d6_row6_col4" class="data row6 col4" >1.115082</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bd7d6_row7_col0" class="data row7 col0" >GJR-GARCH(p=3, q=1)</td>
#       <td id="T_bd7d6_row7_col1" class="data row7 col1" >2.280574</td>
#       <td id="T_bd7d6_row7_col2" class="data row7 col2" >1.060539</td>
#       <td id="T_bd7d6_row7_col3" class="data row7 col3" >1.346115</td>
#       <td id="T_bd7d6_row7_col4" class="data row7 col4" >1.148952</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bd7d6_row8_col0" class="data row8 col0" >GJR-GARCH(p=3, q=2)</td>
#       <td id="T_bd7d6_row8_col1" class="data row8 col1" >2.405239</td>
#       <td id="T_bd7d6_row8_col2" class="data row8 col2" >1.093443</td>
#       <td id="T_bd7d6_row8_col3" class="data row8 col3" >1.276345</td>
#       <td id="T_bd7d6_row8_col4" class="data row8 col4" >1.114378</td>
#     </tr>
#     <tr>
#       <th id="T_bd7d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bd7d6_row9_col0" class="data row9 col0" >GJR-GARCH(p=3, q=3)</td>
#       <td id="T_bd7d6_row9_col1" class="data row9 col1" >2.273395</td>
#       <td id="T_bd7d6_row9_col2" class="data row9 col2" >1.078012</td>
#       <td id="T_bd7d6_row9_col3" class="data row9 col3" >1.350366</td>
#       <td id="T_bd7d6_row9_col4" class="data row9 col4" >1.130329</td>
#     </tr>
#   </tbody>
# </table>

# %%
garch_table = grid_fit_model(daily_realized_volatility=daily_realized_volatility,
                             daily_returns = daily_returns,
                             model_name='APARCH',
                             mse_naive=naive_mse,
                             mae_naive=naive_mae,
                             p_start=1, p_end=2, q_start=1, q_end=2, o_start=0, o_end=1)
plot_table(garch_table)
# Out:
# /opt/conda/lib/python3.10/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# <style type="text/css">
# #T_01de3_row0_col0, #T_01de3_row0_col1, #T_01de3_row0_col2, #T_01de3_row1_col0, #T_01de3_row1_col1, #T_01de3_row1_col2, #T_01de3_row2_col0, #T_01de3_row2_col1, #T_01de3_row2_col2, #T_01de3_row3_col0, #T_01de3_row3_col1, #T_01de3_row3_col2, #T_01de3_row4_col0, #T_01de3_row4_col1, #T_01de3_row4_col2, #T_01de3_row5_col0, #T_01de3_row5_col1, #T_01de3_row5_col2, #T_01de3_row6_col0, #T_01de3_row6_col1, #T_01de3_row6_col2, #T_01de3_row7_col0, #T_01de3_row7_col1, #T_01de3_row7_col2, #T_01de3_row8_col0, #T_01de3_row8_col1, #T_01de3_row8_col2 {
#   text-align: center;
# }
# #T_01de3_row0_col3 {
#   background-color: #d04501;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row0_col4 {
#   background-color: #ab3803;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row1_col3 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row1_col4 {
#   background-color: #ae3903;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row2_col3 {
#   background-color: #812804;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row2_col4, #T_01de3_row4_col3, #T_01de3_row4_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row3_col3 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row3_col4 {
#   background-color: #852904;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row5_col3, #T_01de3_row5_col4, #T_01de3_row8_col3 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
# }
# #T_01de3_row6_col3 {
#   background-color: #8b2c04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row6_col4 {
#   background-color: #892b04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row7_col3 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row7_col4 {
#   background-color: #862a04;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_01de3_row8_col4 {
#   background-color: #feddbc;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_01de3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01de3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_01de3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_01de3_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_01de3_level0_col3" class="col_heading level0 col3" >MSSE</th>
#       <th id="T_01de3_level0_col4" class="col_heading level0 col4" >MASE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01de3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01de3_row0_col0" class="data row0 col0" >naive</td>
#       <td id="T_01de3_row0_col1" class="data row0 col1" >3.070000</td>
#       <td id="T_01de3_row0_col2" class="data row0 col2" >1.219000</td>
#       <td id="T_01de3_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_01de3_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01de3_row1_col0" class="data row1 col0" >APARCH(p=1, q=1, o=0)</td>
#       <td id="T_01de3_row1_col1" class="data row1 col1" >3.502887</td>
#       <td id="T_01de3_row1_col2" class="data row1 col2" >1.224067</td>
#       <td id="T_01de3_row1_col3" class="data row1 col3" >0.876395</td>
#       <td id="T_01de3_row1_col4" class="data row1 col4" >0.995459</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01de3_row2_col0" class="data row2 col0" >APARCH(p=1, q=1, o=1)</td>
#       <td id="T_01de3_row2_col1" class="data row2 col1" >2.394145</td>
#       <td id="T_01de3_row2_col2" class="data row2 col2" >1.092295</td>
#       <td id="T_01de3_row2_col3" class="data row2 col3" >1.282259</td>
#       <td id="T_01de3_row2_col4" class="data row2 col4" >1.115549</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01de3_row3_col0" class="data row3 col0" >APARCH(p=1, q=2, o=0)</td>
#       <td id="T_01de3_row3_col1" class="data row3 col1" >2.458080</td>
#       <td id="T_01de3_row3_col2" class="data row3 col2" >1.108091</td>
#       <td id="T_01de3_row3_col3" class="data row3 col3" >1.248907</td>
#       <td id="T_01de3_row3_col4" class="data row3 col4" >1.099647</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01de3_row4_col0" class="data row4 col0" >APARCH(p=1, q=2, o=1)</td>
#       <td id="T_01de3_row4_col1" class="data row4 col1" >2.368228</td>
#       <td id="T_01de3_row4_col2" class="data row4 col2" >1.090872</td>
#       <td id="T_01de3_row4_col3" class="data row4 col3" >1.296292</td>
#       <td id="T_01de3_row4_col4" class="data row4 col4" >1.117004</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_01de3_row5_col0" class="data row5 col0" >APARCH(p=2, q=1, o=0)</td>
#       <td id="T_01de3_row5_col1" class="data row5 col1" >1700.363307</td>
#       <td id="T_01de3_row5_col2" class="data row5 col2" >4.284880</td>
#       <td id="T_01de3_row5_col3" class="data row5 col3" >0.001805</td>
#       <td id="T_01de3_row5_col4" class="data row5 col4" >0.284374</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_01de3_row6_col0" class="data row6 col0" >APARCH(p=2, q=1, o=1)</td>
#       <td id="T_01de3_row6_col1" class="data row6 col1" >2.465019</td>
#       <td id="T_01de3_row6_col2" class="data row6 col2" >1.118494</td>
#       <td id="T_01de3_row6_col3" class="data row6 col3" >1.245391</td>
#       <td id="T_01de3_row6_col4" class="data row6 col4" >1.089419</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_01de3_row7_col0" class="data row7 col0" >APARCH(p=2, q=2, o=0)</td>
#       <td id="T_01de3_row7_col1" class="data row7 col1" >2.502097</td>
#       <td id="T_01de3_row7_col2" class="data row7 col2" >1.110413</td>
#       <td id="T_01de3_row7_col3" class="data row7 col3" >1.226936</td>
#       <td id="T_01de3_row7_col4" class="data row7 col4" >1.097346</td>
#     </tr>
#     <tr>
#       <th id="T_01de3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_01de3_row8_col0" class="data row8 col0" >APARCH(p=2, q=2, o=1)</td>
#       <td id="T_01de3_row8_col1" class="data row8 col1" >516.516183</td>
#       <td id="T_01de3_row8_col2" class="data row8 col2" >2.813972</td>
#       <td id="T_01de3_row8_col3" class="data row8 col3" >0.005944</td>
#       <td id="T_01de3_row8_col4" class="data row8 col4" >0.433021</td>
#     </tr>
#   </tbody>
# </table>

# %%
garch_table = grid_fit_model(daily_realized_volatility=daily_realized_volatility,
                             daily_returns = daily_returns,
                             model_name='FIGARCH',
                             mse_naive=naive_mse,
                             mae_naive=naive_mae,
                             p_start=0, p_end=1, q_start=0, q_end=1, o_start=0, o_end=1)
plot_table(garch_table)
# Out:
# <style type="text/css">
# #T_29d99_row0_col0, #T_29d99_row0_col1, #T_29d99_row0_col2, #T_29d99_row1_col0, #T_29d99_row1_col1, #T_29d99_row1_col2, #T_29d99_row2_col0, #T_29d99_row2_col1, #T_29d99_row2_col2, #T_29d99_row3_col0, #T_29d99_row3_col1, #T_29d99_row3_col2, #T_29d99_row4_col0, #T_29d99_row4_col1, #T_29d99_row4_col2, #T_29d99_row5_col0, #T_29d99_row5_col1, #T_29d99_row5_col2, #T_29d99_row6_col0, #T_29d99_row6_col1, #T_29d99_row6_col2, #T_29d99_row7_col0, #T_29d99_row7_col1, #T_29d99_row7_col2, #T_29d99_row8_col0, #T_29d99_row8_col1, #T_29d99_row8_col2 {
#   text-align: center;
# }
# #T_29d99_row0_col3 {
#   background-color: #fee7d1;
#   color: #000000;
#   text-align: center;
# }
# #T_29d99_row0_col4 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_29d99_row1_col3, #T_29d99_row2_col3 {
#   background-color: #fd9b50;
#   color: #000000;
#   text-align: center;
# }
# #T_29d99_row1_col4, #T_29d99_row2_col4 {
#   background-color: #fdb170;
#   color: #000000;
#   text-align: center;
# }
# #T_29d99_row3_col3, #T_29d99_row3_col4, #T_29d99_row4_col3, #T_29d99_row4_col4 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
# }
# #T_29d99_row5_col3, #T_29d99_row5_col4, #T_29d99_row6_col3, #T_29d99_row6_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_29d99_row7_col3, #T_29d99_row8_col3 {
#   background-color: #c54102;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_29d99_row7_col4, #T_29d99_row8_col4 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_29d99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29d99_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_29d99_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_29d99_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_29d99_level0_col3" class="col_heading level0 col3" >MSSE</th>
#       <th id="T_29d99_level0_col4" class="col_heading level0 col4" >MASE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29d99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29d99_row0_col0" class="data row0 col0" >naive</td>
#       <td id="T_29d99_row0_col1" class="data row0 col1" >3.070000</td>
#       <td id="T_29d99_row0_col2" class="data row0 col2" >1.219000</td>
#       <td id="T_29d99_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_29d99_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29d99_row1_col0" class="data row1 col0" >FIGARCH(p=0, q=0, o=0)</td>
#       <td id="T_29d99_row1_col1" class="data row1 col1" >2.948334</td>
#       <td id="T_29d99_row1_col2" class="data row1 col2" >1.244500</td>
#       <td id="T_29d99_row1_col3" class="data row1 col3" >1.041237</td>
#       <td id="T_29d99_row1_col4" class="data row1 col4" >0.979115</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29d99_row2_col0" class="data row2 col0" >FIGARCH(p=0, q=0, o=1)</td>
#       <td id="T_29d99_row2_col1" class="data row2 col1" >2.948334</td>
#       <td id="T_29d99_row2_col2" class="data row2 col2" >1.244500</td>
#       <td id="T_29d99_row2_col3" class="data row2 col3" >1.041237</td>
#       <td id="T_29d99_row2_col4" class="data row2 col4" >0.979115</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29d99_row3_col0" class="data row3 col0" >FIGARCH(p=0, q=1, o=0)</td>
#       <td id="T_29d99_row3_col1" class="data row3 col1" >3.113904</td>
#       <td id="T_29d99_row3_col2" class="data row3 col2" >1.275563</td>
#       <td id="T_29d99_row3_col3" class="data row3 col3" >0.985873</td>
#       <td id="T_29d99_row3_col4" class="data row3 col4" >0.955271</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29d99_row4_col0" class="data row4 col0" >FIGARCH(p=0, q=1, o=1)</td>
#       <td id="T_29d99_row4_col1" class="data row4 col1" >3.113904</td>
#       <td id="T_29d99_row4_col2" class="data row4 col2" >1.275563</td>
#       <td id="T_29d99_row4_col3" class="data row4 col3" >0.985873</td>
#       <td id="T_29d99_row4_col4" class="data row4 col4" >0.955271</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29d99_row5_col0" class="data row5 col0" >FIGARCH(p=1, q=0, o=0)</td>
#       <td id="T_29d99_row5_col1" class="data row5 col1" >2.766644</td>
#       <td id="T_29d99_row5_col2" class="data row5 col2" >1.193732</td>
#       <td id="T_29d99_row5_col3" class="data row5 col3" >1.109617</td>
#       <td id="T_29d99_row5_col4" class="data row5 col4" >1.020756</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29d99_row6_col0" class="data row6 col0" >FIGARCH(p=1, q=0, o=1)</td>
#       <td id="T_29d99_row6_col1" class="data row6 col1" >2.766644</td>
#       <td id="T_29d99_row6_col2" class="data row6 col2" >1.193732</td>
#       <td id="T_29d99_row6_col3" class="data row6 col3" >1.109617</td>
#       <td id="T_29d99_row6_col4" class="data row6 col4" >1.020756</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29d99_row7_col0" class="data row7 col0" >FIGARCH(p=1, q=1, o=0)</td>
#       <td id="T_29d99_row7_col1" class="data row7 col1" >2.830709</td>
#       <td id="T_29d99_row7_col2" class="data row7 col2" >1.197778</td>
#       <td id="T_29d99_row7_col3" class="data row7 col3" >1.084503</td>
#       <td id="T_29d99_row7_col4" class="data row7 col4" >1.017307</td>
#     </tr>
#     <tr>
#       <th id="T_29d99_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29d99_row8_col0" class="data row8 col0" >FIGARCH(p=1, q=1, o=1)</td>
#       <td id="T_29d99_row8_col1" class="data row8 col1" >2.830709</td>
#       <td id="T_29d99_row8_col2" class="data row8 col2" >1.197778</td>
#       <td id="T_29d99_row8_col3" class="data row8 col3" >1.084503</td>
#       <td id="T_29d99_row8_col4" class="data row8 col4" >1.017307</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# kL

# %%
rel = (daily_returns.values / daily_realized_volatility[1:].values)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# Assume `rel` is already defined as a numpy array
# You can generate some sample data to simulate `rel`
# rel = np.random.randn(1000)  # Normally distributed data

# 1(a) Plot histogram of `rel` and overlay the normal PDF
plt.figure(figsize=(10, 6))

# Histogram of 'rel'
sns.histplot(rel, bins=30, kde=False, color='blue', stat='density', label='Data Histogram')

# Overlay normal PDF
mean, std = np.mean(rel), np.std(rel)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = stats.norm.pdf(x, mean, std)
plt.plot(x, pdf, 'r', linewidth=2, label=f'Normal PDF\nmean={mean:.2f}, std={std:.2f}')

plt.legend()
plt.title("Histogram of `rel` with Normal PDF")
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# 1(b) Q-Q Plot to compare data quantiles to normal quantiles
plt.figure(figsize=(12, 12))
sm.qqplot(rel, line='45', fit=True, alpha=0.6, color='skyblue')
plt.title("Q-Q Plot of `rel`")
plt.show()

# (Optional) Other illustrative plots like boxplots or density plots
plt.figure(figsize=(12, 12))
sns.boxplot(x=rel, color='cyan')
plt.title("Boxplot of `rel`")
plt.show()

# 2(a) Shapiro-Wilk Test for normality
shapiro_stat, shapiro_p = stats.shapiro(rel)
print(f"Shapiro-Wilk Test: Statistic={shapiro_stat:.4f}, p-value={shapiro_p:.4f}")

# 2(b) Anderson-Darling Test for normality
anderson_stat = stats.anderson(rel)
print(f"Anderson-Darling Test: Statistic={anderson_stat.statistic:.4f}")
for i, critical_value in enumerate(anderson_stat.critical_values):
    sig_level = anderson_stat.significance_level[i]
    print(f"At {sig_level}% significance level: Critical value={critical_value:.4f}")

# 2(c) Kolmogorov-Smirnov Test for normality
ks_stat, ks_p = stats.kstest(rel, 'norm', args=(mean, std))
print(f"Kolmogorov-Smirnov Test: Statistic={ks_stat:.4f}, p-value={ks_p:.4f}")
# Out:
# Shapiro-Wilk Test: Statistic=0.9953, p-value=0.5781
# Anderson-Darling Test: Statistic=0.2720
# At 15.0% significance level: Critical value=0.5680
# At 10.0% significance level: Critical value=0.6470
# At 5.0% significance level: Critical value=0.7760
# At 2.5% significance level: Critical value=0.9050
# At 1.0% significance level: Critical value=1.0770
# Kolmogorov-Smirnov Test: Statistic=0.0358, p-value=0.8626

# %%
plt.figure(figsize=(8, 6))
sm.qqplot(rel, line='45', fit=True, ax=plt.gca(), color='skyblue')
plt.title("Q-Q Plot of `rel`")
plt.gca().get_lines()[0].set_color('skyblue')  # Set the line color to sky blue

# Change point colors
plt.gca().get_lines()[1].set_markerfacecolor('skyblue')  # Change points color
plt.gca().get_lines()[1].set_markeredgecolor('skyblue')  # Change edge color

plt.show()

# %%
sns.set(style="whitegrid")

# Create a figure
plt.figure(figsize=(10, 6))

# Plot histogram
sns.histplot(rel, kde=False, stat="density", bins=30, color='violet', label='Histogram', alpha=0.6)

# Calculate PDF using the normal distribution
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, np.mean(rel), np.std(rel))

# Plot PDF
plt.plot(x, p, 'r', linewidth=2, label='PDF', color='orange')

# Add titles and labels
plt.title('Histogram vs. PDF of `rel`', fontsize=16)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.legend()

# Show the plot
plt.show()

# %%
trd = (daily_realized_volatility - garch_predictions).dropna() + garch_predictions

trrd = (daily_returns - garch_predictions).dropna() + garch_predictions

# %%
plt.scatter(trd, trrd)
